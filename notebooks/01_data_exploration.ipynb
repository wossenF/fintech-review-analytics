# %%
import pandas as pd

df = pd.read_csv("../data/raw/reviews_raw.csv")

df.head()
# Out:
#                                     review  rating        date bank  \
# 0  It's not allowing me to transfer money.       2  2026-05-15  CBE
# 1          IT'S NOT WORK ON HUAWEI DEVICES       4  2026-05-15  CBE
# 2                                      wow       4  2026-05-14  CBE
# 3                                 nice app       5  2026-05-14  CBE
# 4                                formative       5  2026-05-14  CBE
#
#         source
# 0  Google Play
# 1  Google Play
# 2  Google Play
# 3  Google Play
# 4  Google Play

# %%
df.info()
df.isnull().sum()
df.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   review  1200 non-null   object
#  1   rating  1200 non-null   int64
#  2   date    1200 non-null   object
#  3   bank    1200 non-null   object
#  4   source  1200 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 47.0+ KB
# np.int64(20)

# %%
df["rating"].value_counts().sort_index()
# Out:
# rating
# 1    245
# 2     34
# 3     58
# 4     88
# 5    775
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df["rating"].value_counts().sort_index().plot(kind="bar")
plt.title("Rating Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt

df.groupby("bank")["rating"].mean().sort_values().plot(kind="bar")

plt.title("Average Rating by Bank")
plt.ylabel("Average Rating (1–5)")
plt.show()
